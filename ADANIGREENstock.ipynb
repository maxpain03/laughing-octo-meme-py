# %% [markdown]
# # Simple Returns

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as dt
import matplotlib.pyplot as plt

# %%
## Considering Time Frame as 1 year (19 Dec 2019 to 18 Dec 2020)

# %%
adani = dt.DataReader ('ADANIGREEN.NS', data_source = 'yahoo', start = '2019-12-19')
adani
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2019-12-19   135.449997   133.050003   134.949997   134.250000   483204.0
# 2019-12-20   136.399994   134.100006   134.750000   135.100006   617642.0
# 2019-12-23   141.850006   134.750000   135.100006   141.850006  2374429.0
# 2019-12-24   148.899994   145.100006   146.449997   148.899994  1169913.0
# 2019-12-26   156.300003   156.250000   156.300003   156.300003   347718.0
# ...                 ...          ...          ...          ...        ...
# 2020-12-14  1028.099976   995.099976  1019.000000  1010.799988   921358.0
# 2020-12-15  1020.000000  1000.250000  1009.000000  1013.650024   754880.0
# 2020-12-16  1029.900024  1011.099976  1019.750000  1019.400024   451443.0
# 2020-12-17  1059.400024  1013.750000  1023.900024  1041.550049   686579.0
# 2020-12-18  1058.400024  1001.000000  1058.400024  1016.150024  1037435.0
#
#               Adj Close
# Date
# 2019-12-19   134.250000
# ...

# %%
# Now Finding Simple returns for Adani Green comapany's stock listed on NSE

# %%
adani['simple_return'] = (adani['Adj Close'] / adani['Adj Close'].shift(1)) - 1

# %%
adani['simple_return']
# Out:
# Date
# 2019-12-19         NaN
# 2019-12-20    0.006332
# 2019-12-23    0.049963
# 2019-12-24    0.049700
# 2019-12-26    0.049698
#                 ...
# 2020-12-14   -0.029477
# 2020-12-15    0.002820
# 2020-12-16    0.005673
# 2020-12-17    0.021728
# 2020-12-18   -0.024387
# Name: simple_return, Length: 250, dtype: float64

# %%
adani['simple_return'].plot(figsize = (10, 5))

# %%
# Average for total observations

# %%
avg = round(adani['simple_return'].mean(),5)
avg
# Out:
# 0.00879

# %%
# Stock market is active for 250 days in a year hence average should be multiplied by 250

# %%
avg = avg*250
avg
# Out:
# 2.1975

# %%
print (str(round(avg,5) * 100) + '%')
# Out:
# 219.74999999999997%

# %% [markdown]
# # Logarithmic Returns

# %%
adani ['log_return'] = np.log(adani['Adj Close']/adani['Adj Close'].shift(1))

print (adani['log_return'])
# Out:
# Date
# 2019-12-19         NaN
# 2019-12-20    0.006312
# 2019-12-23    0.048755
# 2019-12-24    0.048505
# 2019-12-26    0.048502
#                 ...
# 2020-12-14   -0.029920
# 2020-12-15    0.002816
# 2020-12-16    0.005657
# 2020-12-17    0.021496
# 2020-12-18   -0.024689
# Name: log_return, Length: 250, dtype: float64

# %%
adani ['log_return'].plot(figsize = (8,5))
plt.show()

# %%
# Now the daily average of Log returns is:

# %%
adani_daily = round(adani['log_return'].mean(),5)
adani_daily
# Out:
# 0.00813

# %%
# Converting this into 250 working days of a year

# %%
adani_annual = round(adani_daily * 250, 5)
adani_annual
# Out:
# 2.0325

# %%
print (str(round(adani_annual,5) * 100) + '%')
# Out:
# 203.25000000000003%
